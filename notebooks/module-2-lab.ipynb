# %% [markdown]
# # Module 2 Lab: Attack-Path Modeling and Breach Forecasting
#
# **Course:** AINS6302 AI for Risk Assessment
#
# **Assessed on:** [**ANUBIS**](https://anubis.castalia.institute) under course `ains6302`.
#
# ## Brief
#
# Construct an attack graph from a synthetic network map and identify the top-5 attack paths to a crown-jewel asset. Fit a Bayesian network to propagate compromise probabilities, and forecast next-quarter breach likelihood with uncertainty.
#
# ## Rules
#
# - Put all of your work in this notebook.
# - The autograder imports functions by name; do not rename them.
# - Submit by pushing to the `main` branch of your ANUBIS-provisioned repo.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Part 1 — Baseline
#
# *Implement the baseline described in the module brief.*

# %%
def baseline(x):
    """Return a baseline prediction for x. Autograded."""
    # TODO: implement
    return 0

# %% [markdown]
# ## Part 2 — Improvement
#
# *Implement the improvement described in the module brief.*

# %%
def improved(x):
    """Return an improved prediction for x. Autograded."""
    # TODO: implement
    return 0

# %% [markdown]
# ## Part 3 — Short writeup
#
# *In 200-400 words, explain your approach, what worked, and what did not.*
#
# *(Write your answer here.)*
