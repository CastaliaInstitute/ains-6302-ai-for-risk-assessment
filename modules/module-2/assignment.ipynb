# %% [markdown]
# # Module 2 Assignment: Attack-Path Modeling and Breach Forecasting
#
# *In-book assignment for AINS6302 AI for Risk Assessment. This is the Thebe-enabled practice version; the graded version lives in `notebooks/module-2-lab.ipynb` and is assessed on **ANUBIS** (NetHunter + AI; not NYU *Anubis LMS*).*
#
# ## Learning objective
#
# Models the enterprise as a graph and asks: given what an attacker can see, what is the likeliest path to crown-jewel assets, and how does risk evolve over time? Covers attack graphs, Bayesian networks, and time-series forecasting.
#
# ## Exercises

# %% [markdown]
# ### Exercise 1 — Warm-up
#
# Briefly define, in your own words:
#
# - Attack graphs and shortest-path-to-impact analysis
# - Bayesian networks for compromise propagation
# - Time-series forecasting of breach likelihood
# - Communicating uncertainty to non-technical stakeholders

# %%
# Exercise 2 — Applied warm-up
# TODO: replace with your solution.
import numpy as np
import pandas as pd

rng = np.random.default_rng(0)
data = pd.DataFrame({'x': rng.normal(size=100)})
data.describe()

# %% [markdown]
# ### Exercise 3 — Synthesis
#
# Write 1-2 paragraphs relating the warm-ups above to the module lab brief: *Construct an attack graph from a synthetic network map and identify the top-5 attack paths to a crown-jewel asset. Fit a Bayesian network to propagate compromise probabilities, and forecast next-quarter breach likelihood with uncertainty.*
