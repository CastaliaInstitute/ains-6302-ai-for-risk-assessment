# %% [markdown]
# # Module 1 Assignment: Quantitative Risk and Vulnerability Prioritization
#
# *In-book assignment for AINS6302 AI for Risk Assessment. This is the Thebe-enabled practice version; the graded version lives in `notebooks/module-1-lab.ipynb` and is assessed on **ANUBIS** (NetHunter + AI; not NYU *Anubis LMS*).*
#
# ## Learning objective
#
# Translates qualitative risk talk into numbers executives can act on. Students build FAIR-style loss distributions, apply EPSS and KEV feeds to prioritize patching, and critique the assumptions behind each score.
#
# ## Exercises

# %% [markdown]
# ### Exercise 1 — Warm-up
#
# Briefly define, in your own words:
#
# - The FAIR model: loss event frequency and magnitude
# - CVSS, EPSS, and the KEV catalog — what each actually measures
# - Monte Carlo simulation of annualized loss
# - Prioritization as a budgeted optimization problem

# %%
# Exercise 2 — Applied warm-up
# TODO: replace with your solution.
import numpy as np
import pandas as pd

rng = np.random.default_rng(0)
data = pd.DataFrame({'x': rng.normal(size=100)})
data.describe()

# %% [markdown]
# ### Exercise 3 — Synthesis
#
# Write 1-2 paragraphs relating the warm-ups above to the module lab brief: *Given a synthetic asset inventory and a CVE feed, build a FAIR-style Monte Carlo simulator and produce a patch prioritization ranked by expected loss reduction per dollar.*
